# %%
from env.environment import EmailEnv
from env.models import Action

env = EmailEnv()
obs = env.reset()
print(obs)
# Out:
# email_text='Win a free iPhone now!!!' sender='unknown' urgency_hint='low'

# %%
from env.models import Action
from env.grader import grade

# Example email truth
truth = {"type": "important", "priority": "high"}

# Example agent action
action = Action(category="important", priority="high", response="I will handle this ASAP.")

score = grade(action, truth)
print("Score:", score)
# Out:
# Score: 1.0

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-your-key")  # replace with a dummy key for test
print("OpenAI imported successfully")
# Out:
# OpenAI imported successfully
